# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
# Use "pip install citipy"
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Make URL with api key and imperial units to get Fahrenheit temperatures
url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="

#Make lists to store city name, cloudiness, country, date, humidity, lat, lng, max temp, and wind speed
name = []
clouds = []
country = []
date = []
humidity = []
lat = []
lng = []
mTemp = []
windSpd = []

#Make for loop 
z=0
while z < 5:
    for x in cities:
#print out string that says it's searching for the city
#Starter while loop to test code before pulling big numbers
    
        print(f"Searching for {x} at index {z}..." )
#Make new url by adding city to end of URL

        response = requests.get(url+x).json()
        #Try to append the name to list by response['name']
        try:
            name.append(response['name'])
            clouds.append(response['clouds']['all'])
            country.append(response['sys']['country'])
            date.append(response['dt'])
            humidity.append(response['main']['humidity'])
            lat.append(response['coord']['lat'])
            lng.append(response['coord']['lon'])
            mTemp.append(response['main']['temp_max'])
            windSpd.append(response['wind']['speed'])
        #Except if name doesn't exist in list
        #print out that the city wasn't found
        except:
            print("City does not exist. Skipping...")
            z += 1
            pass
        z += 1
        #Next city
# Out:
# 7...
# Searching for bredasdorp at index 158...
# Searching for ostrovnoy at index 159...
# Searching for saint george at index 160...
# Searching for lagoa at index 161...
# Searching for upernavik at index 162...
# Searching for tumannyy at index 163...
# City does not exist. Skipping...
# Searching for vanavara at index 165...
# Searching for verkhnyaya inta at index 166...
# Searching for karaul at index 167...
# City does not exist. Skipping...
# Searching for gornyy at index 169...
# Searching for dubbo at index 170...
# Searching for leningradskiy at index 171...
# Searching for moranbah at index 172...
# Searching for anchorage at index 173...
# Searching for gushikawa at index 174...
# Searching for cody at index 175...
# Searching for yekaterinoslavka at index 176...
# Searching for eureka at index 177...
# Searching for qaanaaq at index 178...
# Searching for bijie at index 179...
# Searching for souillac at index 180...
# Searching for saskylakh at index 181...
# Searching for ust-nera at index 182...
# Searching for la tuque at index 183...
# Searching for los llanos de aridane at index 184...
# Searching for sakakah at index 185...
# Searching for cap-aux-meules at index 186...
# Searching for lebu at index 187...
# Searching for igrim at index 188...
# Searching for thinadhoo at index 189...
# Searching for sitka at index 190...
# Searching for karratha at index 191...
# Searching for himora at index 192...
# City does not exist. Skipping...
# Searching for cabo san lucas at index 194...
# Searching for tabalosos at index 195...
# Searching for troitskoye at index 196...
# Searching for abnub at index 197...
# Searching for namanga at index 198...
# Searching for buin at index 199...
# Searching for mrirt at index 200...
# City does not exist. Skipping...
# Searching for yumen at index 202...
# Searching for ponta do sol at index 203...
# Searching for miri at index 204...
# Searching for bintulu at index 205...
# Searching for bryanka at index 206...
# Searching for pangnirtung at index 207...
# Searching for raposa at index 208...
# Searching for oktyabrskiy at index 209...
# Searching for walvis bay at index 210...
# Searching for changying at index 211...
# Searching for kamaishi at index 212...
# Searching for klaksvik at index 213...
# Searching for bac lieu at index 214...
# Searching for vrangel at index 215...
# Searching for mayor pablo lagerenza at index 216...
# Searching for mezen at index 217...
# Searching for fortuna at index 218...
# Searching for aripuana at index 219...
# Searching for port hueneme at index 220...
# Searching for yulara at index 221...
# Searching for loukhi at index 222...
# Searching for yellandu at index 223...
# Searching for deputatskiy at index 224...
# Searching for jalu at index 225...
# Searching for baker at index 226...
# Searching for talara at index 227...
# Searching for kenai at index 228...
# Searching for stykkisholmur at index 229...
# Searching for sao joao da barra at index 230...
# Searching for bolshegrivskoye at index 231...
# City does not exist. Skipping...
# Searching for kudahuvadhoo at index 233...
# Searching for mancio lima at index 234...
# Searching for hithadhoo at index 235...
# Searching for gornozavodsk at index 236...
# Searching for hanstholm at index 237...
# Searching for seoul at index 238...
# Searching for atka at index 239...
# City does not exist. Skipping...
# Searching for esperance at index 241...
# Searching for gallup at index 242...
# Searching for butaritari at index 243...
# Searching for surt at index 244...
# Searching for havoysund at index 245...
# Searching for kaitangata at index 246...
# Searching for bethel at index 247...
# Searching for faanui at index 248...
# Searching for provideniya at index 249...
# Searching for poum at index 250...
# Searching for harnosand at index 251...
# Searching for taltal at index 252...
# Searching for turtas at index 253...
# Searching for pokhara at index 254...
# Searching for afsin at index 255...
# Searching for mecca at index 256...
# Searching for lashio at index 257...
# Searching for soanierana ivongo at index 258...
# Searching for natitingou at index 259...
# Searching for bengkulu at index 260...
# Searching for guerrero negro at index 261...
# Searching for isangel at index 262...
# Searching for neiafu at index 263...
# Searching for saint-pierre at index 264...
# Searching for savonlinna at index 265...
# Searching for likasi at index 266...
# Searching for hofn at index 267...
# Searching for shirokiy at index 268...
# Searching for portland at index 269...
# Searching for moose factory at index 270...
# Searching for lavrentiya at index 271...
# Searching for wawa at index 272...
# Searching for kota belud at index 273...
# Searching for shawinigan at index 274...
# Searching for sao felix do xingu at index 275...
# Searching for ilo at index 276...
# Searching for west bay at index 277...
# Searching for raudeberg at index 278...
# Searching for adre at index 279...
# Searching for istra at index 280...
# Searching for galveston at index 281...
# Searching for dubrovnik at index 282...
# Searching for garowe at index 283...
# Searching for guarapuava at index 284...
# Searching for katsuura at index 285...
# Searching for narasannapeta at index 286...
# Searching for marihatag at index 287...
# Searching for sinnamary at index 288...
# Searching for kingsport at index 289...
# Searching for winnemucca at index 290...
# Searching for ribeira grande at index 291...
# Searching for high level at index 292...
# Searching for hutchinson at index 293...
# Searching for amalfi at index 294...
# Searching for jalpan at index 295...
# Searching for trincomalee at index 296...
# Searching for carmelo at index 297...
# Searching for ksenyevka at index 298...
# City does not exist. Skipping...
# Searching for abha at index 300...
# Searching for lasa at index 301...
# Searching for yarmouth at index 302...
# Searching for mindelo at index 303...
# Searching for khor at index 304...
# Searching for hasaki at index 305...
# Searching for nacozari at index 306...
# Searching for brae at index 307...
# Searching for yermakovskoye at index 308...
# Searching for hangu at index 309...
# Searching for haines junction at index 310...
# Searching for santa rosa at index 311...
# Searching for brigantine at index 312...
# Searching for kurilsk at index 313...
# Searching for huntsville at index 314...
# Searching for yeola at index 315...
# Searching for caconda at index 316...
# Searching for kushima at index 317...
# Searching for paciran at index 318...
# Searching for paita at index 319...
# Searching for suao at index 320...
# City does not exist. Skipping...
# Searching for stamsund at index 322...
# City does not exist. Skipping...
# Searching for talnakh at index 324...
# Searching for broken hill at index 325...
# Searching for samalaeulu at index 326...
# City does not exist. Skipping...
# Searching for clyde river at index 328...
# Searching for northam at index 329...
# Searching for mahenge at index 330...
# Searching for vaitape at index 331...
# Searching for isabela at index 332...
# Searching for chara at index 333...
# Searching for solnechnyy at index 334...
# Searching for touros at index 335...
# Searching for cherskiy at index 336...
# Searching for ahipara at index 337...
# Searching for marawi at index 338...
# Searching for nuuk at index 339...
# Searching for atambua at index 340...
# Searching for santa fe at index 341...
# Searching for kindia at index 342...
# Searching for saleaula at index 343...
# City does not exist. Skipping...
# Searching for samarkand at index 345...
# Searching for cayenne at index 346...
# Searching for panjab at index 347...
# Searching for ust-maya at index 348...
# Searching for dubno at index 349...
# Searching for johnston at index 350...
# Searching for udachnyy at index 351...
# Searching for kandi at index 352...
# Searching for san onofre at index 353...
# Searching for san jose at index 354...
# Searching for rocha at index 355...
# Searching for tupelo at index 356...
# Searching for umzimvubu at index 357...
# City does not exist. Skipping...
# Searching for saldanha at index 359...
# Searching for attawapiskat at index 360...
# City does not exist. Skipping...
# Searching for batemans bay at index 362...
# Searching for mahadday weyne at index 363...
# City does not exist. Skipping...
# Searching for fort nelson at index 365...
# Searching for palu at index 366...
# Searching for westport at index 367...
# Searching for lingao at index 368...
# Searching for takoradi at index 369...
# Searching for innoshima at index 370...
# Searching for thung song at index 371...
# Searching for pemangkat at index 372...
# Searching for ewa beach at index 373...
# Searching for westlock at index 374...
# Searching for kalininsk at index 375...
# Searching for gawler at index 376...
# Searching for praia at index 377...
# Searching for qingdao at index 378...
# Searching for rudbar at index 379...
# Searching for ola at index 380...
# Searching for copiapo at index 381...
# Searching for butembo at index 382...
# Searching for arkhangelos at index 383...
# City does not exist. Skipping...
# Searching for tabou at index 385...
# Searching for abay at index 386...
# Searching for coos bay at index 387...
# Searching for huazolotitlan at index 388...
# City does not exist. Skipping...
# Searching for truckee at index 390...
# Searching for srednekolymsk at index 391...
# Searching for vallenar at index 392...
# Searching for zachagansk at index 393...
# City does not exist. Skipping...
# Searching for caravelas at index 395...
# Searching for dubai at index 396...
# Searching for mount gambier at index 397...
# Searching for mackay at index 398...
# Searching for urengoy at index 399...
# Searching for zrece at index 400...
# Searching for magadan at index 401...
# Searching for port augusta at index 402...
# Searching for afmadu at index 403...
# City does not exist. Skipping...
# Searching for hokitika at index 405...
# Searching for placerville at index 406...
# Searching for bilma at index 407...
# Searching for denpasar at index 408...
# Searching for bonavista at index 409...
# Searching for gotsu at index 410...
# Searching for adrar at index 411...
# Searching for san vicente at index 412...
# Searching for kidal at index 413...
# Searching for camalu at index 414...
# Searching for cairns at index 415...
# Searching for pangai at index 416...
# Searching for viedma at index 417...
# Searching for najran at index 418...
# Searching for osmanabad at index 419...
# Searching for kilindoni at index 420...
# Searching for chifeng at index 421...
# Searching for liboro at index 422...
# Searching for asau at index 423...
# Searching for whitianga at index 424...
# Searching for bakchar at index 425...
# Searching for tukrah at index 426...
# Searching for polson at index 427...
# Searching for the valley at index 428...
# Searching for gamboma at index 429...
# Searching for kemi at index 430...
# Searching for pisco at index 431...
# Searching for bambous virieux at index 432...
# Searching for eniwa at index 433...
# Searching for maputo at index 434...
# Searching for severo-yeniseyskiy at index 435...
# Searching for lake havasu city at index 436...
# Searching for sinkat at index 437...
# City does not exist. Skipping...
# Searching for meadville at index 439...
# Searching for natal at index 440...
# Searching for sept-iles at index 441...
# Searching for taranagar at index 442...
# Searching for saltillo at index 443...
# Searching for rafai at index 444...
# Searching for codrington at index 445...
# Searching for zhanaozen at index 446...
# Searching for salalah at index 447...
# Searching for hibbing at index 448...
# Searching for synya at index 449...
# Searching for olinda at index 450...
# Searching for shahpur at index 451...
# Searching for georgetown at index 452...
# Searching for uruguaiana at index 453...
# Searching for kampong chhnang at index 454...
# Searching for uyovu at index 455...
# Searching for masty at index 456...
# Searching for nouakchott at index 457...
# Searching for wilhelmsburg at index 458...
# Searching for yaring at index 459...
# Searching for warqla at index 460...
# City does not exist. Skipping...
# Searching for berlevag at index 462...
# Searching for anori at index 463...
# Searching for bulgan at index 464...
# Searching for san angelo at index 465...
# Searching for fomboni at index 466...
# Searching for lehi at index 467...
# Searching for esmeraldas at index 468...
# Searching for broome at index 469...
# Searching for namatanai at index 470...
# Searching for biak at index 471...
# Searching for asilah at index 472...
# Searching for houston at index 473...
# Searching for vao at index 474...
# Searching for outlook at index 475...
# Searching for boguchany at index 476...
# Searching for naze at index 477...
# Searching for kawalu at index 478...
# Searching for tsihombe at index 479...
# City does not exist. Skipping...
# Searching for saquarema at index 481...
# Searching for rensvik at index 482...
# Searching for fort saint james at index 483...
# Searching for sao raimundo das mangabeiras at index 484...
# Searching for juniyah at index 485...
# City does not exist. Skipping...
# Searching for buchanan at index 487...
# Searching for xining at index 488...
# Searching for ambon at index 489...
# Searching for fort-shevchenko at index 490...
# Searching for strezhevoy at index 491...
# Searching for urucui at index 492...
# Searching for pevek at index 493...
# Searching for antsohihy at index 494...
# Searching for weyburn at index 495...
# Searching for babanusah at index 496...
# City does not exist. Skipping...
# Searching for inuvik at index 498...
# Searching for villa rica at index 499...
# Searching for monrovia at index 500...
# Searching for council bluffs at index 501...
# Searching for savinskiy at index 502...
# Searching for nabire at index 503...
# Searching for nanortalik at index 504...
# Searching for kaduqli at index 505...
# Searching for luganville at index 506...
# Searching for norman wells at index 507...
# Searching for dunedin at index 508...
# Searching for veraval at index 509...
# Searching for vestmannaeyjar at index 510...
# Searching for amuntai at index 511...
# Searching for chernyshevskiy at index 512...
# Searching for ayan at index 513...
# Searching for port-de-bouc at index 514...
# Searching for psebay at index 515...
# Searching for ketchikan at index 516...
# Searching for komsomolskiy at index 517...
# Searching for baracoa at index 518...
# Searching for hay river at index 519...
# Searching for makakilo city at index 520...
# Searching for sosva at index 521...
# Searching for shenzhen at index 522...
# Searching for xenia at index 523...
# Searching for shelburne at index 524...
# Searching for aksu at index 525...
# Searching for dicabisagan at index 526...
# Searching for flin flon at index 527...
# Searching for guanica at index 528...
# Searching for half moon bay at index 529...
# Searching for santa cruz at index 530...
# Searching for clive at index 531...
# Searching for nouadhibou at index 532...
# Searching for chicama at index 533...
# Searching for shenkursk at index 534...
# Searching for ndele at index 535...
# Searching for rolim de moura at index 536...
# City does not exist. Skipping...
# Searching for beyneu at index 538...
# Searching for kieta at index 539...
# Searching for athens at index 540...
# Searching for college at index 541...
# Searching for puerto carreno at index 542...
# Searching for le port at index 543...
# Searching for bajil at index 544...
# Searching for suntar at index 545...
# Searching for gouyave at index 546...
# Searching for chakulia at index 547...
# Searching for impfondo at index 548...
# Searching for mongo at index 549...
# Searching for bhanpura at index 550...
# Searching for micheweni at index 551...
# Searching for itoman at index 552...
# Searching for qasigiannguit at index 553...
# Searching for jabiru at index 554...
# City does not exist. Skipping...
# Searching for gijon at index 556...
# Searching for zhengjiatun at index 557...
# Searching for storforshei at index 558...
# Searching for chapais at index 559...
# Searching for christchurch at index 560...
# Searching for olafsvik at index 561...
# Searching for usinsk at index 562...
# Searching for nadym at index 563...
# Searching for port blair at index 564...
# Searching for puerto escondido at index 565...
# Searching for lima at index 566...
# Searching for comodoro rivadavia at index 567...
# Searching for magistralnyy at index 568...
# Searching for nichinan at index 569...
# Searching for kalispell at index 570...
# Searching for pacific grove at index 571...
# Searching for iracoubo at index 572...
# Searching for saint augustine at index 573...
# Searching for saint-joseph at index 574...
# Searching for visakhapatnam at index 575...
# Searching for axim at index 576...
# Searching for roebourne at index 577...
# Searching for arman at index 578...
# Searching for chone at index 579...
# Searching for azanka at index 580...
# Searching for egvekinot at index 581...
# Searching for sioux falls at index 582...
# Searching for comarapa at index 583...
# Searching for dwarka at index 584...
# Searching for sinjar at index 585...
# Searching for nemuro at index 586...
# Searching for baghmara at index 587...
# Searching for mocuba at index 588...
# Searching for picayune at index 589...
# Searching for serenje at index 590...
# Searching for kondoa at index 591...
# Searching for topeka at index 592...
# Searching for lolua at index 593...
# City does not exist. Skipping...
# Searching for buraydah at index 595...
# Searching for mafra at index 596...
# Searching for mentok at index 597...
# City does not exist. Skipping...
# Searching for daura at index 599...
# Searching for krasnoyarsk-45 at index 600...
# City does not exist. Skipping...
# Searching for kingori at index 602...
# Searching for rosetta at index 603...
# Searching for havre at index 604...
# Searching for tual at index 605...
# Searching for port hedland at index 606...
# Searching for tobermory at index 607...
# Searching for shizunai at index 608...
# Searching for tarata at index 609...
# Searching for gat at index 610...
# Searching for zunheboto at index 611...
# Searching for alice springs at index 612...
# Searching for pestretsy at index 613...
# Searching for paamiut at index 614...
# Searching for el cobre at index 615...
# Searching for samarai at index 616...
# Searching for qui nhon at index 617...
# Searching for hamadan at index 618...
# Searching for acapulco at index 619...
# Searching for catalina at index 620...
# Searching for chiungutwa at index 621...
# Searching for yatou at index 622...
# Searching for severo-kurilsk at index 623...
# Searching for dembi dolo at index 624...
# Searching for barsovo at index 625...
# Searching for castelo at index 626...
# Searching for kamenka at index 627...
# Searching for havelock at index 628...
# Searching for oranjestad at index 629...
# Searching for sisimiut at index 630...
# Searching for muros at index 631...
# Searching for palabuhanratu at index 632...
# City does not exist. Skipping...
# Searching for siguiri at index 634...
# Searching for roros at index 635...
# Searching for huarmey at index 636...
# Searching for kavaratti at index 637...
# Searching for rungata at index 638...
# City does not exist. Skipping...
# Searching for bayan at index 640...
# Searching for kaberamaido at index 641...
# Searching for mackenzie at index 642...
# Searching for sharjah at index 643...
# Searching for tabiauea at index 644...
# City does not exist. Skipping...
# Searching for qafsah at index 646...
# City does not exist. Skipping...
# Searching for reci at index 648...
# Searching for numaligarh at index 649...
# Searching for cootamundra at index 650...
# Searching for redmond at index 651...
# Searching for tungkang at index 652...
# City does not exist. Skipping...
# Searching for tarko-sale at index 654...
# Searching for kumi at index 655...
# Searching for kamenskoye at index 656...
# City does not exist. Skipping...
# Searching for ukiah at index 658...
# Searching for nizhniy tsasuchey at index 659...
# Searching for pochutla at index 660...
# Searching for grand river south east at index 661...
# City does not exist. Skipping...
# Searching for borzya at index 663...
# Searching for maceio at index 664...
# Searching for aasiaat at index 665...
# Searching for plettenberg bay at index 666...
# Searching for sur at index 667...
# Searching for villa carlos paz at index 668...
# Searching for boende at index 669...
# Searching for pahrump at index 670...
# Searching for vostok at index 671...
# Searching for gidole at index 672...
# Searching for santo tomas at index 673...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Make dictionaries of the list of the city weather properties
weather_dict ={
    "Name":name,
    "Cloudiness":clouds,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Latitude":lat,
    "Longitude":lng,
    "Max Temp": mTemp,
    "Wind Speed":windSpd
}
#Make dataframe from the list
weather_data = pd.DataFrame(weather_dict)

#Print the DataFrame
weather_data.head()
# Out:
#          Name  Cloudiness Countr        Date  Humidity  Latitude  Longtidue  \
# 0       Kapaa          75     US  1583978582        69     22.08    -159.32
# 1      Lompoc           1     US  1583978646        67     34.64    -120.46
# 2    Tasiilaq          95     GL  1583978607        51     65.61     -37.64
# 3  Nkhotakota          86     MW  1583978887        76    -12.93      34.30
# 4      Albany          75     US  1583978770        51     42.60     -73.97
#
#    Max Temp  Wind Speed
# 0     80.60       10.29
# 1     64.00        8.05
# 2     12.20       14.99
# 3     79.65       13.71
# 4     39.00        5.82

# %%
#Print out the dataframe
weather_data.to_csv("output_data/cities.csv",index=False,header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data['Latitude'],weather_data['Max Temp'])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data['Latitude'],weather_data['Humidity'])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data['Latitude'],weather_data['Cloudiness'])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data['Latitude'],weather_data['Wind Speed'])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def LinReg(x,y):
    #Using scipy stats to make linear regression equation
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept

    #Make the line
    global line_eq
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.plot(x,regress_values,"r-")
    r_squared = rvalue*rvalue
    print("The r squared value is: " + str(r_squared))

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = weather_data.loc[weather_data["Latitude"] >= 0,:]
south_df = weather_data.loc[weather_data["Latitude"] <= 0,:]
print(north_df.head())
print(south_df.head())
# Out:
# Name  Cloudiness Countr        Date  Humidity  Latitude  Longtidue  \
# 0     Kapaa          75     US  1583978582        69     22.08    -159.32
# 1    Lompoc           1     US  1583978646        67     34.64    -120.46
# 2  Tasiilaq          95     GL  1583978607        51     65.61     -37.64
# 4    Albany          75     US  1583978770        51     42.60     -73.97
# 5      Atar           0     MR  1583979025         8     20.52     -13.05
#
#    Max Temp  Wind Speed
# 0      80.6       10.29
# 1      64.0        8.05
# 2      12.2       14.99
# 4      39.0        5.82
# 5      66.9        6.46
#            Name  Cloudiness Countr        Date  Humidity  Latitude  Longtidue  \
# 3    Nkhotakota          86     MW  1583978887        76    -12.93      34.30
# 6       Mataura           1     NZ  1583979025        68    -46.19     168.86
# 9   East London         100     ZA  1583979026        85    -33.02      27.91
# 13      Rikitea           4     PF  1583979026        76    -23.12    -134.97
# 14        Brejo         100     BR  1583978954        97     -3.68     -42.75
#
#     Max Temp  Wind Speed
# 3      79.65       13.71
# 6      59.00       13.00
# 9      71.74       11.14
# 13     77.65       12.12
# 14     74.34        2.71

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Print graph for the data
plt.scatter(north_df['Latitude'],north_df['Max Temp'])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature\nin the Northern Hemisphere")
#Call LinReg using Latitude and Temp
LinReg(north_df['Latitude'],north_df['Max Temp'])
#Make regression line and overlay on the graph
#print(line_eq)
plt.annotate(line_eq,(0,20),fontsize=15,color="red")
plt.show()
# Out:
# The r squared value is: 0.7795343602809334

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Print graph for the data
plt.scatter(south_df['Latitude'],south_df['Max Temp'])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature\nin the Southern Hemisphere")
#Call LinReg using Latitude and Temp
LinReg(south_df['Latitude'],south_df['Max Temp'])
#Make regression line and overlay on the graph
#print(line_eq)
plt.annotate(line_eq,(-50,80),fontsize=12,color="red")
plt.show()
# Out:
# The r squared value is: 0.2110767088570152

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Print graph for the data
plt.scatter(north_df['Latitude'],north_df['Humidity'])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity\n in the Northern Hemisphere")
#Call LinReg using Latitude and Temp
LinReg(north_df['Latitude'],north_df['Humidity'])
#Make regression line and overlay on the graph
#print(line_eq)
plt.annotate(line_eq,(50,30),fontsize=12,color="red")
plt.show()
# Out:
# The r squared value is: 0.0881657205750145

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Print graph for the data
plt.scatter(south_df['Latitude'],south_df['Humidity'])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity\nin the Southern Hemisphere")
#Call LinReg using Latitude and Temp
LinReg(south_df['Latitude'],south_df['Humidity'])
#Make regression line and overlay on the graph
#print(line_eq)
plt.annotate(line_eq,(-50,75),fontsize=12,color="red")
plt.show()
# Out:
# The r squared value is: 0.08626109603401348

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Print graph for the data
plt.scatter(north_df['Latitude'],north_df['Cloudiness'])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness\nin the Northern Hemisphere")
#Call LinReg using Latitude and Temp
LinReg(north_df['Latitude'],north_df['Cloudiness'])
#Make regression line and overlay on the graph
#print(line_eq)
plt.annotate(line_eq,(45,50),fontsize=15,color="red")
plt.show()
# Out:
# The r squared value is: 0.09090651218671045

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Print graph for the data
plt.scatter(south_df['Latitude'],south_df['Cloudiness'])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness\n in the Southern Hemisphere")
#Call LinReg using Latitude and Temp
LinReg(south_df['Latitude'],south_df['Cloudiness'])
#Make regression line and overlay on the graph
#print(line_eq)
plt.annotate(line_eq,(-20,50),fontsize=12,color="red")
plt.show()
# Out:
# The r squared value is: 0.030111505159962915

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Print graph for the data
plt.scatter(north_df['Latitude'],north_df['Wind Speed'])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed\n in the Northern Hemisphere")
#Call LinReg using Latitude and Temp
LinReg(north_df['Latitude'],north_df['Wind Speed'])
#Make regression line and overlay on the graph
#print(line_eq)
plt.annotate(line_eq,(50,0),fontsize=12,color="red")
plt.show()
# Out:
# The r squared value is: 0.03923769126343472

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Print graph for the data
plt.scatter(south_df['Latitude'],south_df['Wind Speed'])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph")
plt.title("City Latitude vs Wind Speed\n in the Southern Hemisphere")
#Call LinReg using Latitude and Temp
LinReg(south_df['Latitude'],south_df['Wind Speed'])
#Make regression line and overlay on the graph
#print(line_eq)
plt.annotate(line_eq,(-50,6),fontsize=12,color="red")
plt.show()
# Out:
# The r squared value is: 0.07161670833123611
